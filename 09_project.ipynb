# %%
from dotenv import load_dotenv
from langchain_ollama import OllamaLLM
from langchain_openai import ChatOpenAI
import os

load_dotenv()

print(os.getenv("OPENAI_API_KEY"))

llm = ChatOpenAI(model="gpt-4.1-nano", temperature=0.2)
# Out:
# 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

# %%
from langchain.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

from stock_info import Stock

prompt = ChatPromptTemplate.from_messages([
    ("system", """
        Want assistance provided by qualified individuals enabled with experience on understanding 
        charts using technical analysis tools while interpreting macroeconomic environment 
        prevailing across world consequently assisting customers acquire long term advantages 
        requires clear verdicts therefore seeking same through informed predictions written down 
        precisely! First statement contains following content- “Can you tell us what future stock 
        market looks like based upon current conditions ?"
     """),
    ("user", """
        {company} 주식에 투자해도 될까요? 
        아래의 기본정보, 재무제표를 참고해 마크다운 형식의 투자 보고서를 한글로 작성해 주세요.

        기본정보:
        {basic_info}
     
        재무제표:
        {financial_statement}
     """)
])

output_parser = StrOutputParser()

chain = prompt | llm | output_parser

company = "Microsoft"
symbol = "MSFT"

stock = Stock(symbol)

response = chain.invoke({
    "company": company,
    "basic_info": stock.get_basic_info(),
    "financial_statement": stock.get_financial_statement()
})
print(response)
# Out:
# # Microsoft 주식 투자 분석 보고서
#
# ## 1. 회사 개요
# - **회사명:** Microsoft Corporation
# - **산업군:** 소프트웨어 - 인프라
# - **섹터:** 기술
# - **시가총액:** 약 3.41조 달러
# - **발행주식수:** 약 74억 3천만 주
#
# ## 2. 재무 성과 분석
#
# ### 2.1 손익계산서 (최근 분기 기준)
# | 항목             | 2025-03-31 | 2024-12-31 | 2024-09-30 | 2024-06-30 | 2024-03-31 |
# |------------------|------------|------------|------------|------------|------------|
# | 총수익           | 70.07억 달러 | 69.63억 달러 | 65.59억 달러 | 64.73억 달러 | 61.86억 달러 |
# | 매출총이익       | 48.15억 달러 | 47.83억 달러 | 45.49억 달러 | 45.04억 달러 | 43.35억 달러 |
# | 영업이익         | 32.0억 달러  | 31.65억 달러 | 30.55억 달러 | 27.93억 달러 | 27.58억 달러 |
# | 순이익           | 25.82억 달러 | 24.11억 달러 | 24.67억 달러 | 22.03억 달러 | 21.94억 달러 |
#
# ### 2.2 재무상태표
# | 항목                     | 2025-03-31 | 2024-12-31 | 2024-09-30 | 2024-06-30 | 2024-03-31 |
# |--------------------------|------------|------------|------------|------------|------------|
# | 총자산                   | 562.62억 달러 | 533.90억 달러 | 523.01억 달러 | 512.16억 달러 | 484.28억 달러 |
# | 부채 및 지분 (총 부채)   | 240.73억 달러 | 231.20억 달러 | 235.29억 달러 | 243.69억 달러 | 231.12억 달러 |
# | 자기자본 (지분)          | 321.89억 달러 | 302.69억 달러 | 287.72억 달러 | 268.48억 달러 | 253.15억 달러 |
#
# ### 2.3 현금흐름표
# | 항목                     | 2025-03-31 | 2024-12-31 | 2024-09-30 | 2024-06-30 | 2024-03-31 |
# |--------------------------|------------|------------|------------|------------|------------|
# | 영업활동 현금흐름        | 370.44억 달러 | 222.91억 달러 | 341.80억 달러 | 371.95억 달러 | 319.17억 달러 |
# | 투자활동 현금흐름        | -127.14억 달러 | -141.12억 달러 | -152.01억 달러 | -148.48억 달러 | -107.00억 달러 |
# | 재무활동 현금흐름        | -130.36억 달러 | -112.43억 달러 | -165.76억 달러 | -235.63억 달러 | -188.08억 달러 |
#
# ## 3. 투자 판단
# Microsoft는 안정적인 재무구조와 꾸준한 수익성을 보여주고 있습니다. 최근 분기별 매출과 순이익이 지속적으로 성장하는 모습이며, 높은 시가총액과 막대한 현금흐름은 기업의 재무적 안정성을 뒷받침합니다. 또한, 기술 섹터 내에서도 선도적인 위치를 차지하고 있어 장기적인 성장 잠재력을 기대할 수 있습니다.
#
# ## 4. 결론
# 현재의 재무상태와 시장 위치를 고려할 때, Microsoft는 장기 투자에 적합한 우량 기업으로 판단됩니다. 다만, 글로벌 경제 환경과 기술 산업의 경쟁 심화, 규제 변화 등에 따른 리스크도 함께 고려해야 하며, 투자 결정 전 추가적인 시장 분석과 개인의 투자 성향을 반영하는 것이 바람직합니다.
#
# ---
#
# **참고:** 본 보고서는 공개된 재무자료와 시장 정보를 바탕으로 작성되었으며, 투자 결정은 본인의 책임 하에 이루어져야 합니다.

# %%
import pandas as pd

df = pd.read_csv("nasdaq_screener_1747634138847.csv", na_filter=False)
df.head()
# Out:
#   Symbol                                               Name Last Sale  \
# 0      A             Agilent Technologies Inc. Common Stock   $113.77
# 1     AA                    Alcoa Corporation Common Stock     $29.40
# 2   AACB  Artius II Acquisition Inc. Class A Ordinary Sh...    $10.03
# 3  AACBR                  Artius II Acquisition Inc. Rights   $0.2399
# 4  AACBU                   Artius II Acquisition Inc. Units    $10.22
#
#    Net Change % Change      Market Cap        Country IPO Year   Volume  \
# 0      1.3700   1.219%  32436136113.00  United States     1999  1811951
# 1      0.7300   2.546%   7611728737.00  United States     2016  8793712
# 2      0.0200    0.20%            0.00  United States     2025    14059
# 3      0.0049   2.085%            0.00  United States     2025      346
# 4      0.0100   0.098%            0.00  United States     2025     1034
#
#         Sector                                          Industry
# 0  Industrials  Biotechnology: Laboratory Analytical Instruments
# 1  Industrials                                          Aluminum
# 2
# 3
# 4      Finance                                      Blank Checks

# %%
df[df['Symbol'].str.contains(r'[/^ ]', regex=True)]
# Out:
#       Symbol                                               Name Last Sale  \
# 36     ABR^D  Arbor Realty Trust 6.375% Series D Cumulative ...  $17.4023
# 37     ABR^E  Arbor Realty Trust 6.25% Series E Cumulative R...  $16.7875
# 38     ABR^F  Arbor Realty Trust 6.25% Series F Fixed-to-Flo...    $20.75
# 77     ACP^A  abrdn Income Credit Strategies Fund 5.250% Ser...   $21.595
# 79     ACR^C  ACRES Commercial Realty Corp. 8.625% Fixed-to-...    $24.90
# ...      ...                                                ...       ...
# 6755   WRB^F  W.R. Berkley Corporation 5.10% Subordinated De...    $19.28
# 6756   WRB^G  W.R. Berkley Corporation 4.25% Subordinated De...    $16.28
# 6757   WRB^H  W.R. Berkley Corporation 4.125% Subordinated D...    $15.90
# 6771   WSO/B                                        Watsco Inc.   $471.49
# 6815  XFLT^A  XAI Octagon Floating Rate & Alternative Income...   $25.135
#
#       Net Change % Change Market Cap        Country IPO Year  Volume Sector  \
# 36       -0.0977  -0.558%             United States             8272
# 37        0.0575   0.344%             United States             4094
# 38       -0.0500   -0.24%             United States            17926
# 77        0.4450   2.104%             United States              980
# 79       -0.0200   -0.08%             United States            10400
# ...          ...      ...        ...            ...      ...     ...    ...
# 6755      0.0100   0.052%             United States            58373
# 6756      0.0200   0.123%             United States             9742
# 6757      0.0100   0.063%             United States             6861
# 6771      0.0000    0.00%             United States              428
# 6815      0.0050    0.02%             United States              676
#
#      Industry
# 36
# 37
# 38
# 77
# 79
# ...       ...
# 6755
# 6756
# 6757
# 6771
# 6815
#
# [401 rows x 11 columns]

# %%
df['id'] = df['Symbol'].str.strip().replace(r'[/^]', '_', regex=True)
df.head()
# Out:
#   Symbol                                               Name Last Sale  \
# 0      A             Agilent Technologies Inc. Common Stock   $113.77
# 1     AA                    Alcoa Corporation Common Stock     $29.40
# 2   AACB  Artius II Acquisition Inc. Class A Ordinary Sh...    $10.03
# 3  AACBR                  Artius II Acquisition Inc. Rights   $0.2399
# 4  AACBU                   Artius II Acquisition Inc. Units    $10.22
#
#    Net Change % Change      Market Cap        Country IPO Year   Volume  \
# 0      1.3700   1.219%  32436136113.00  United States     1999  1811951
# 1      0.7300   2.546%   7611728737.00  United States     2016  8793712
# 2      0.0200    0.20%            0.00  United States     2025    14059
# 3      0.0049   2.085%            0.00  United States     2025      346
# 4      0.0100   0.098%            0.00  United States     2025     1034
#
#         Sector                                          Industry     id
# 0  Industrials  Biotechnology: Laboratory Analytical Instruments      A
# 1  Industrials                                          Aluminum     AA
# 2                                                                  AACB
# 3                                                                 AACBR
# 4      Finance                                      Blank Checks  AACBU

# %%
result_d = df.to_dict(orient='records')
result_d
# Out:
# [{'Symbol': 'A',
#   'Name': 'Agilent Technologies Inc. Common Stock',
#   'Last Sale': '$113.77',
#   'Net Change': 1.37,
#   '% Change': '1.219%',
#   'Market Cap': '32436136113.00',
#   'Country': 'United States',
#   'IPO Year': '1999',
#   'Volume': 1811951,
#   'Sector': 'Industrials',
#   'Industry': 'Biotechnology: Laboratory Analytical Instruments',
#   'id': 'A'},
#  {'Symbol': 'AA',
#   'Name': 'Alcoa Corporation Common Stock ',
#   'Last Sale': '$29.40',
#   'Net Change': 0.73,
#   '% Change': '2.546%',
#   'Market Cap': '7611728737.00',
#   'Country': 'United States',
#   'IPO Year': '2016',
#   'Volume': 8793712,
#   'Sector': 'Industrials',
#   'Industry': 'Aluminum',
#   'id': 'AA'},
#  {'Symbol': 'AACB',
#   'Name': 'Artius II Acquisition Inc. Class A Ordinary Shares',
#   'Last Sale': '$10.03',
#   'Net Change': 0.02,
#   '% Change': '0.20%',
#   'Market Cap': '0.00',
#   'Country': 'United States',
#   'IPO Year': '2025',
#   'Volume': 14059,
#   'Sector': '',
#   'Industry': '',
#   'id': 'AACB'},
#  {'Symbol': 'AACBR',
#   'Name': 'Artius II Acquisition Inc. Rights',
#   'Last Sale': '$0.2399',
#   'Net Change': 0.0049,
#   '% Change': '2.085%',
#   'Market Cap': '0.00',
#   'Country': 'United States',
#   'IPO Year': '2025',
#   'Volume': 346,
#   'Sector': '',
#   'Industry': '',
#   'id': 'AACBR'},
#  {'Symbol': 'AACBU',
#   'Name': 'Artius II Acquisition Inc. Units',
#   'Last Sale': '$10.22',
#   'Net Change': 0.01,
#   '% Change': '0.098%',
#   'Market Cap': '0.00',
#   'Country': 'United States',
#   'IPO Year': '2025',
#   'Volume': 1034,
#   'Sector': 'Finance',
#   'Industry': 'Blank Checks',
#   'id': 'AACBU'},
#  {'Symbol': 'AACG',
#   'Name': 'ATA Creativity Global American Depositary Shares',
#   'Last Sale': '$0.9199',
#   'Net Change': -0.0201,
#   '% Change': '-2.138%',
#   'Market Cap': '29355285.00',
#   'Country': 'China',
#   'IPO Year': '2008',
#   'Volume': 48791,
#   'Sector': 'Real Estate',
#   'Industry': 'Other Consumer Services',
#   'id': 'AACG'},
#  {'Symbol': 'AACT',
#   'Name': 'Ares Acquisition Corporation II Class A Ordinary Shares',
#   'Last Sale': '$11.27',
#   'Net Change': -0.01,
#   '% Change': '-0.089%',
#   'Market Cap': '0.00',
#   'Country': '',
#   'IPO Year': '2023',
#   'Volume': 1067807,
#   'Sector': 'Finance',
#   'Industry': 'Blank Checks',
#   'id': 'AACT'},
#  {'Symbol': 'AAL',
#   'Name': 'American Airlines Group Inc. Common Stock',
#   'Last Sale': '$11.86',
#   'Net Change': 0.1,
#   '% Change': '0.85%',
#   'Market Cap': '7821816364.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 46757134,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Air Freight/Delivery Services',
#   'id': 'AAL'},
#  {'Symbol': 'AAM',
#   'Name': 'AA Mission Acquisition Corp. Class A Ordinary Shares',
#   'Last Sale': '$10.32',
#   'Net Change': -0.04,
#   '% Change': '-0.386%',
#   'Market Cap': '0.00',
#   'Country': '',
#   'IPO Year': '2024',
#   'Volume': 217334,
#   'Sector': '',
#   'Industry': '',
#   'id': 'AAM'},
#  {'Symbol': 'AAME',
#   'Name': 'Atlantic American Corporation Common Stock',
#   'Last Sale': '$1.72',
#   'Net Change': -0.06,
#   '% Change': '-3.371%',
#   'Market Cap': '35083232.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 5235,
#   'Sector': 'Finance',
#   'Industry': 'Life Insurance',
#   'id': 'AAME'},
#  {'Symbol': 'AAMI',
#   'Name': 'Acadian Asset Management Inc. Common Stock',
#   'Last Sale': '$30.24',
#   'Net Change': -0.26,
#   '% Change': '-0.852%',
#   'Market Cap': '1082449116.00',
#   'Country': 'United Kingdom',
#   'IPO Year': '2014',
#   'Volume': 761499,
#   'Sector': 'Finance',
#   'Industry': 'Investment Managers',
#   'id': 'AAMI'},
#  {'Symbol': 'AAOI',
#   'Name': 'Applied Optoelectronics Inc. Common Stock',
#   'Last Sale': '$18.69',
#   'Net Change': -0.18,
#   '% Change': '-0.954%',
#   'Market Cap': '1038123976.00',
#   'Country': 'United States',
#   'IPO Year': '2013',
#   'Volume': 3090890,
#   'Sector': 'Technology',
#   'Industry': 'Semiconductors',
#   'id': 'AAOI'},
#  {'Symbol': 'AAON',
#   'Name': 'AAON Inc. Common Stock',
#   'Last Sale': '$106.87',
#   'Net Change': 2.76,
#   '% Change': '2.651%',
#   'Market Cap': '8695599168.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 443976,
#   'Sector': 'Industrials',
#   'Industry': 'Industrial Machinery/Components',
#   'id': 'AAON'},
#  {'Symbol': 'AAP',
#   'Name': 'Advance Auto Parts Inc.',
#   'Last Sale': '$35.03',
#   'Net Change': 0.61,
#   '% Change': '1.772%',
#   'Market Cap': '2094546898.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 2399327,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Auto & Home Supply Stores',
#   'id': 'AAP'},
#  {'Symbol': 'AAPG',
#   'Name': 'Ascentage Pharma Group International American Depository Shares',
#   'Last Sale': '$22.65',
#   'Net Change': 0.095,
#   '% Change': '0.421%',
#   'Market Cap': '1972059509.00',
#   'Country': 'China',
#   'IPO Year': '2025',
#   'Volume': 4835,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'AAPG'},
#  {'Symbol': 'AAPL',
#   'Name': 'Apple Inc. Common Stock',
#   'Last Sale': '$211.26',
#   'Net Change': -0.19,
#   '% Change': '-0.09%',
#   'Market Cap': '3155342600760.00',
#   'Country': 'United States',
#   'IPO Year': '1980',
#   'Volume': 53649120,
#   'Sector': 'Technology',
#   'Industry': 'Computer Manufacturing',
#   'id': 'AAPL'},
#  {'Symbol': 'AARD',
#   'Name': 'Aardvark Therapeutics Inc. Common Stock',
#   'Last Sale': '$9.89',
#   'Net Change': 0.8,
#   '% Change': '8.801%',
#   'Market Cap': '214572649.00',
#   'Country': 'United States',
#   'IPO Year': '2025',
#   'Volume': 19150,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'AARD'},
#  {'Symbol': 'AAT',
#   'Name': 'American Assets Trust Inc. Common Stock',
#   'Last Sale': '$19.94',
#   'Net Change': 0.29,
#   '% Change': '1.476%',
#   'Market Cap': '1219026516.00',
#   'Country': 'United States',
#   'IPO Year': '2011',
#   'Volume': 265148,
#   'Sector': 'Real Estate',
#   'Industry': 'Real Estate Investment Trusts',
#   'id': 'AAT'},
#  {'Symbol': 'AB',
#   'Name': 'AllianceBernstein Holding L.P.  Units',
#   'Last Sale': '$40.73',
#   'Net Change': 0.29,
#   '% Change': '0.717%',
#   'Market Cap': '4508798740.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 279349,
#   'Sector': 'Finance',
#   'Industry': 'Investment Managers',
#   'id': 'AB'},
#  {'Symbol': 'ABAT',
#   'Name': 'American Battery Technology Company Common Stock',
#   'Last Sale': '$1.55',
#   'Net Change': -0.03,
#   '% Change': '-1.899%',
#   'Market Cap': '131219916.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 3777153,
#   'Sector': 'Basic Materials',
#   'Industry': 'Metal Mining',
#   'id': 'ABAT'},
#  {'Symbol': 'ABBV',
#   'Name': 'AbbVie Inc. Common Stock',
#   'Last Sale': '$184.02',
#   'Net Change': 2.34,
#   '% Change': '1.288%',
#   'Market Cap': '325053485029.00',
#   'Country': 'United States',
#   'IPO Year': '2012',
#   'Volume': 6151323,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'ABBV'},
#  {'Symbol': 'ABCB',
#   'Name': 'Ameris Bancorp Common Stock',
#   'Last Sale': '$63.45',
#   'Net Change': 0.17,
#   '% Change': '0.269%',
#   'Market Cap': '4372398128.00',
#   'Country': 'United States',
#   'IPO Year': '1994',
#   'Volume': 381055,
#   'Sector': 'Finance',
#   'Industry': 'Major Banks',
#   'id': 'ABCB'},
#  {'Symbol': 'ABCL',
#   'Name': 'AbCellera Biologics Inc. Common Shares',
#   'Last Sale': '$2.03',
#   'Net Change': 0.01,
#   '% Change': '0.495%',
#   'Market Cap': '598171030.00',
#   'Country': 'Canada',
#   'IPO Year': '2020',
#   'Volume': 3385655,
#   'Sector': 'Health Care',
#   'Industry': 'Pharmaceuticals and Biotechnology',
#   'id': 'ABCL'},
#  {'Symbol': 'ABEO',
#   'Name': 'Abeona Therapeutics Inc. Common Stock',
#   'Last Sale': '$6.10',
#   'Net Change': 0.31,
#   '% Change': '5.354%',
#   'Market Cap': '296056168.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 1396147,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'ABEO'},
#  {'Symbol': 'ABEV',
#   'Name': 'Ambev S.A. American Depositary Shares (Each representing 1 Common Share)',
#   'Last Sale': '$2.55',
#   'Net Change': 0.01,
#   '% Change': '0.394%',
#   'Market Cap': '39924226024.00',
#   'Country': 'Brazil',
#   'IPO Year': '2013',
#   'Volume': 18751487,
#   'Sector': 'Consumer Staples',
#   'Industry': 'Beverages (Production/Distribution)',
#   'id': 'ABEV'},
#  {'Symbol': 'ABG',
#   'Name': 'Asbury Automotive Group Inc Common Stock',
#   'Last Sale': '$235.07',
#   'Net Change': 1.39,
#   '% Change': '0.595%',
#   'Market Cap': '4621278741.00',
#   'Country': 'United States',
#   'IPO Year': '2002',
#   'Volume': 101739,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Retail-Auto Dealers and Gas Stations',
#   'id': 'ABG'},
#  {'Symbol': 'ABL',
#   'Name': 'Abacus Global Management Inc. Class A Common Stock',
#   'Last Sale': '$8.91',
#   'Net Change': -0.05,
#   '% Change': '-0.558%',
#   'Market Cap': '862960577.00',
#   'Country': 'United States',
#   'IPO Year': '2020',
#   'Volume': 312753,
#   'Sector': 'Finance',
#   'Industry': 'Investment Managers',
#   'id': 'ABL'},
#  {'Symbol': 'ABLLL',
#   'Name': 'Abacus Global Management Inc. 9.875% Fixed Rate Senior Notes due 2028',
#   'Last Sale': '$25.4401',
#   'Net Change': -0.0299,
#   '% Change': '-0.117%',
#   'Market Cap': '1899137733.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 4191,
#   'Sector': 'Finance',
#   'Industry': 'Investment Managers',
#   'id': 'ABLLL'},
#  {'Symbol': 'ABLLW',
#   'Name': 'Abacus Global Management Inc. Warrant',
#   'Last Sale': '$1.85',
#   'Net Change': 0.01,
#   '% Change': '0.543%',
#   'Market Cap': '179178122.00',
#   'Country': 'United States',
#   'IPO Year': '2020',
#   'Volume': 9578,
#   'Sector': 'Finance',
#   'Industry': 'Investment Managers',
#   'id': 'ABLLW'},
#  {'Symbol': 'ABLV',
#   'Name': 'Able View Global Inc. Class B Ordinary Shares',
#   'Last Sale': '$1.22',
#   'Net Change': 0.01,
#   '% Change': '0.826%',
#   'Market Cap': '60255705.00',
#   'Country': 'China',
#   'IPO Year': '',
#   'Volume': 7818,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Other Consumer Services',
#   'id': 'ABLV'},
#  {'Symbol': 'ABM',
#   'Name': 'ABM Industries Incorporated Common Stock',
#   'Last Sale': '$52.64',
#   'Net Change': 0.34,
#   '% Change': '0.65%',
#   'Market Cap': '3275862844.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 380871,
#   'Sector': 'Finance',
#   'Industry': 'Diversified Commercial Services',
#   'id': 'ABM'},
#  {'Symbol': 'ABNB',
#   'Name': 'Airbnb Inc. Class A Common Stock',
#   'Last Sale': '$138.00',
#   'Net Change': 1.21,
#   '% Change': '0.885%',
#   'Market Cap': '86444960190.00',
#   'Country': 'United States',
#   'IPO Year': '2020',
#   'Volume': 3683925,
#   'Sector': 'Finance',
#   'Industry': 'Diversified Commercial Services',
#   'id': 'ABNB'},
#  {'Symbol': 'ABOS',
#   'Name': 'Acumen Pharmaceuticals Inc. Common Stock',
#   'Last Sale': '$1.07',
#   'Net Change': 0.06,
#   '% Change': '5.941%',
#   'Market Cap': '64813565.00',
#   'Country': 'United States',
#   'IPO Year': '2021',
#   'Volume': 165356,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Biological Products (No Diagnostic Substances)',
#   'id': 'ABOS'},
#  {'Symbol': 'ABP',
#   'Name': 'Abpro Holdings Inc Common Stock',
#   'Last Sale': '$0.23',
#   'Net Change': -0.0351,
#   '% Change': '-13.24%',
#   'Market Cap': '12010457.00',
#   'Country': 'United States',
#   'IPO Year': '2022',
#   'Volume': 16133185,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'ABP'},
#  {'Symbol': 'ABPWW',
#   'Name': 'Abpro Holdings Inc. Warrant',
#   'Last Sale': '$0.02',
#   'Net Change': 0.0,
#   '% Change': '0.00%',
#   'Market Cap': '1044388.00',
#   'Country': 'United States',
#   'IPO Year': '2022',
#   'Volume': 19052,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'ABPWW'},
#  {'Symbol': 'ABR',
#   'Name': 'Arbor Realty Trust Common Stock',
#   'Last Sale': '$10.57',
#   'Net Change': -0.27,
#   '% Change': '-2.491%',
#   'Market Cap': '2031133652.00',
#   'Country': 'United States',
#   'IPO Year': '2004',
#   'Volume': 3418462,
#   'Sector': 'Real Estate',
#   'Industry': 'Real Estate Investment Trusts',
#   'id': 'ABR'},
#  {'Symbol': 'ABR^D',
#   'Name': 'Arbor Realty Trust 6.375% Series D Cumulative Redeemable Preferred Stock Liquidation Preference $25.00 per Share',
#   'Last Sale': '$17.4023',
#   'Net Change': -0.0977,
#   '% Change': '-0.558%',
#   'Market Cap': '',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 8272,
#   'Sector': '',
#   'Industry': '',
#   'id': 'ABR_D'},
#  {'Symbol': 'ABR^E',
#   'Name': 'Arbor Realty Trust 6.25% Series E Cumulative Redeemable Preferred Stock',
#   'Last Sale': '$16.7875',
#   'Net Change': 0.0575,
#   '% Change': '0.344%',
#   'Market Cap': '',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 4094,
#   'Sector': '',
#   'Industry': '',
#   'id': 'ABR_E'},
#  {'Symbol': 'ABR^F',
#   'Name': 'Arbor Realty Trust 6.25% Series F Fixed-to-Floating Rate Cumulative Redeemable Preferred Stock Liquidation Preference $25.00 per share',
#   'Last Sale': '$20.75',
#   'Net Change': -0.05,
#   '% Change': '-0.24%',
#   'Market Cap': '',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 17926,
#   'Sector': '',
#   'Industry': '',
#   'id': 'ABR_F'},
#  {'Symbol': 'ABSI',
#   'Name': 'Absci Corporation Common Stock',
#   'Last Sale': '$2.88',
#   'Net Change': -0.08,
#   '% Change': '-2.703%',
#   'Market Cap': '367370934.00',
#   'Country': 'United States',
#   'IPO Year': '2021',
#   'Volume': 2898262,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Commercial Physical & Biological Resarch',
#   'id': 'ABSI'},
#  {'Symbol': 'ABT',
#   'Name': 'Abbott Laboratories Common Stock',
#   'Last Sale': '$134.80',
#   'Net Change': 1.45,
#   '% Change': '1.087%',
#   'Market Cap': '234529955482.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 7128622,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'ABT'},
#  {'Symbol': 'ABTS',
#   'Name': 'Abits Group Inc Ordinary Shares',
#   'Last Sale': '$3.79',
#   'Net Change': 0.59,
#   '% Change': '18.438%',
#   'Market Cap': '8982827.00',
#   'Country': 'China',
#   'IPO Year': '',
#   'Volume': 140855,
#   'Sector': 'Technology',
#   'Industry': 'Computer Software: Programming Data Processing',
#   'id': 'ABTS'},
#  {'Symbol': 'ABUS',
#   'Name': 'Arbutus Biopharma Corporation Common Stock',
#   'Last Sale': '$3.08',
#   'Net Change': -0.04,
#   '% Change': '-1.282%',
#   'Market Cap': '589758979.00',
#   'Country': 'Canada',
#   'IPO Year': '',
#   'Volume': 1052601,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'ABUS'},
#  {'Symbol': 'ABVC',
#   'Name': 'ABVC BioPharma Inc. Common Stock',
#   'Last Sale': '$1.48',
#   'Net Change': 0.27,
#   '% Change': '22.314%',
#   'Market Cap': '24824426.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 465259,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'ABVC'},
#  {'Symbol': 'ABVE',
#   'Name': 'Above Food Ingredients Inc. Common Stock',
#   'Last Sale': '$1.32',
#   'Net Change': 0.08,
#   '% Change': '6.452%',
#   'Market Cap': '36702081.00',
#   'Country': 'Canada',
#   'IPO Year': '',
#   'Volume': 350202,
#   'Sector': 'Consumer Staples',
#   'Industry': 'Packaged Foods',
#   'id': 'ABVE'},
#  {'Symbol': 'ABVEW',
#   'Name': 'Above Food Ingredients Inc. Warrants',
#   'Last Sale': '$0.043',
#   'Net Change': -0.0029,
#   '% Change': '-6.318%',
#   'Market Cap': '1195598.00',
#   'Country': 'Canada',
#   'IPO Year': '',
#   'Volume': 30932,
#   'Sector': 'Consumer Staples',
#   'Industry': 'Packaged Foods',
#   'id': 'ABVEW'},
#  {'Symbol': 'ABVX',
#   'Name': 'Abivax SA American Depositary Shares',
#   'Last Sale': '$6.01',
#   'Net Change': 0.02,
#   '% Change': '0.334%',
#   'Market Cap': '380933591.00',
#   'Country': 'France',
#   'IPO Year': '2023',
#   'Volume': 120156,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'ABVX'},
#  {'Symbol': 'AC',
#   'Name': 'Associated Capital Group Inc. Common Stock',
#   'Last Sale': '$37.09',
#   'Net Change': -0.5,
#   '% Change': '-1.33%',
#   'Market Cap': '783996440.00',
#   'Country': 'United States',
#   'IPO Year': '2015',
#   'Volume': 3619,
#   'Sector': 'Finance',
#   'Industry': 'Investment Bankers/Brokers/Service',
#   'id': 'AC'},
#  {'Symbol': 'ACA',
#   'Name': 'Arcosa Inc. Common Stock ',
#   'Last Sale': '$88.99',
#   'Net Change': 0.71,
#   '% Change': '0.804%',
#   'Market Cap': '4344143582.00',
#   'Country': 'United States',
#   'IPO Year': '2018',
#   'Volume': 259708,
#   'Sector': 'Industrials',
#   'Industry': 'Metal Fabrications',
#   'id': 'ACA'},
#  {'Symbol': 'ACAD',
#   'Name': 'ACADIA Pharmaceuticals Inc. Common Stock',
#   'Last Sale': '$22.26',
#   'Net Change': 4.66,
#   '% Change': '26.477%',
#   'Market Cap': '3725474803.00',
#   'Country': 'United States',
#   'IPO Year': '1985',
#   'Volume': 17783947,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'ACAD'},
#  {'Symbol': 'ACB',
#   'Name': 'Aurora Cannabis Inc. Common Shares',
#   'Last Sale': '$5.13',
#   'Net Change': 0.17,
#   '% Change': '3.427%',
#   'Market Cap': '280409786.00',
#   'Country': 'Canada',
#   'IPO Year': '',
#   'Volume': 1726099,
#   'Sector': 'Health Care',
#   'Industry': ' Medicinal Chemicals and Botanical Products ',
#   'id': 'ACB'},
#  {'Symbol': 'ACCO',
#   'Name': 'Acco Brands Corporation Common Stock',
#   'Last Sale': '$3.86',
#   'Net Change': -0.04,
#   '% Change': '-1.026%',
#   'Market Cap': '347782352.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 951712,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Publishing',
#   'id': 'ACCO'},
#  {'Symbol': 'ACCS',
#   'Name': 'ACCESS Newswire Inc. Common Stock',
#   'Last Sale': '$9.00',
#   'Net Change': 0.01,
#   '% Change': '0.111%',
#   'Market Cap': '34629687.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 3710,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Publishing',
#   'id': 'ACCS'},
#  {'Symbol': 'ACDC',
#   'Name': 'ProFrac Holding Corp. Class A Common Stock',
#   'Last Sale': '$6.13',
#   'Net Change': -0.15,
#   '% Change': '-2.389%',
#   'Market Cap': '981893788.00',
#   'Country': 'United States',
#   'IPO Year': '2022',
#   'Volume': 1171981,
#   'Sector': 'Energy',
#   'Industry': 'Oilfield Services/Equipment',
#   'id': 'ACDC'},
#  {'Symbol': 'ACEL',
#   'Name': 'Accel Entertainment Inc. ',
#   'Last Sale': '$11.71',
#   'Net Change': -0.1,
#   '% Change': '-0.847%',
#   'Market Cap': '991149471.00',
#   'Country': 'United States',
#   'IPO Year': '2017',
#   'Volume': 296164,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Services-Misc. Amusement & Recreation',
#   'id': 'ACEL'},
#  {'Symbol': 'ACET',
#   'Name': 'Adicet Bio Inc. Common Stock ',
#   'Last Sale': '$0.7772',
#   'Net Change': 0.1392,
#   '% Change': '21.818%',
#   'Market Cap': '64281921.00',
#   'Country': 'United States',
#   'IPO Year': '2018',
#   'Volume': 1934986,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'ACET'},
#  {'Symbol': 'ACGL',
#   'Name': 'Arch Capital Group Ltd. Common Stock',
#   'Last Sale': '$94.59',
#   'Net Change': 1.05,
#   '% Change': '1.123%',
#   'Market Cap': '35448030520.00',
#   'Country': 'Bermuda',
#   'IPO Year': '',
#   'Volume': 1113307,
#   'Sector': 'Finance',
#   'Industry': 'Property-Casualty Insurers',
#   'id': 'ACGL'},
#  {'Symbol': 'ACGLN',
#   'Name': 'Arch Capital Group Ltd. Depositary Shares each Representing a 1/1000th Interest in a 4.550% Non-Cumulative Preferred Share Series G',
#   'Last Sale': '$16.94',
#   'Net Change': 0.03,
#   '% Change': '0.177%',
#   'Market Cap': '6348341654.00',
#   'Country': 'Bermuda',
#   'IPO Year': '',
#   'Volume': 50828,
#   'Sector': 'Finance',
#   'Industry': 'Property-Casualty Insurers',
#   'id': 'ACGLN'},
#  {'Symbol': 'ACGLO',
#   'Name': 'Arch Capital Group Ltd. Depositary Shares Each Representing 1/1000th Interest in a Share of 5.45% Non-Cumulative Preferred Shares Series F',
#   'Last Sale': '$20.56',
#   'Net Change': 0.02,
#   '% Change': '0.097%',
#   'Market Cap': '7704953034.00',
#   'Country': 'Bermuda',
#   'IPO Year': '',
#   'Volume': 16315,
#   'Sector': 'Finance',
#   'Industry': 'Property-Casualty Insurers',
#   'id': 'ACGLO'},
#  {'Symbol': 'ACHC',
#   'Name': 'Acadia Healthcare Company Inc. Common Stock',
#   'Last Sale': '$26.15',
#   'Net Change': 0.51,
#   '% Change': '1.989%',
#   'Market Cap': '2408994562.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 2120582,
#   'Sector': 'Health Care',
#   'Industry': 'Medical Specialities',
#   'id': 'ACHC'},
#  {'Symbol': 'ACHR',
#   'Name': 'Archer Aviation Inc. Class A Common Stock',
#   'Last Sale': '$13.30',
#   'Net Change': 1.11,
#   '% Change': '9.106%',
#   'Market Cap': '7301847085.00',
#   'Country': 'United States',
#   'IPO Year': '2020',
#   'Volume': 71585878,
#   'Sector': 'Industrials',
#   'Industry': 'Aerospace',
#   'id': 'ACHR'},
#  {'Symbol': 'ACHV',
#   'Name': 'Achieve Life Sciences Inc. Common Shares',
#   'Last Sale': '$3.08',
#   'Net Change': 0.35,
#   '% Change': '12.821%',
#   'Market Cap': '106830022.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 564770,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: In Vitro & In Vivo Diagnostic Substances',
#   'id': 'ACHV'},
#  {'Symbol': 'ACI',
#   'Name': 'Albertsons Companies Inc. Class A Common Stock',
#   'Last Sale': '$22.10',
#   'Net Change': 0.2,
#   '% Change': '0.913%',
#   'Market Cap': '12724071840.00',
#   'Country': 'United States',
#   'IPO Year': '2020',
#   'Volume': 4788436,
#   'Sector': 'Consumer Staples',
#   'Industry': 'Food Chains',
#   'id': 'ACI'},
#  {'Symbol': 'ACIC',
#   'Name': 'American Coastal Insurance Corporation Common Stock',
#   'Last Sale': '$11.06',
#   'Net Change': 0.06,
#   '% Change': '0.545%',
#   'Market Cap': '534788737.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 438238,
#   'Sector': 'Finance',
#   'Industry': 'Property-Casualty Insurers',
#   'id': 'ACIC'},
#  {'Symbol': 'ACIU',
#   'Name': 'AC Immune SA Common Stock',
#   'Last Sale': '$1.71',
#   'Net Change': 0.14,
#   '% Change': '8.917%',
#   'Market Cap': '171701745.00',
#   'Country': 'Switzerland',
#   'IPO Year': '2016',
#   'Volume': 90077,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'ACIU'},
#  {'Symbol': 'ACIW',
#   'Name': 'ACI Worldwide Inc. Common Stock',
#   'Last Sale': '$48.87',
#   'Net Change': 0.1,
#   '% Change': '0.205%',
#   'Market Cap': '5126445651.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 734543,
#   'Sector': 'Technology',
#   'Industry': 'Computer Software: Prepackaged Software',
#   'id': 'ACIW'},
#  {'Symbol': 'ACLS',
#   'Name': 'Axcelis Technologies Inc. Common Stock',
#   'Last Sale': '$61.58',
#   'Net Change': -1.09,
#   '% Change': '-1.739%',
#   'Market Cap': '1978536950.00',
#   'Country': 'United States',
#   'IPO Year': '2000',
#   'Volume': 394569,
#   'Sector': 'Technology',
#   'Industry': 'Industrial Machinery/Components',
#   'id': 'ACLS'},
#  {'Symbol': 'ACLX',
#   'Name': 'Arcellx Inc. Common Stock',
#   'Last Sale': '$58.78',
#   'Net Change': 0.33,
#   '% Change': '0.565%',
#   'Market Cap': '3239172002.00',
#   'Country': 'United States',
#   'IPO Year': '2022',
#   'Volume': 626744,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Biological Products (No Diagnostic Substances)',
#   'id': 'ACLX'},
#  {'Symbol': 'ACM',
#   'Name': 'AECOM Common Stock',
#   'Last Sale': '$109.37',
#   'Net Change': 1.09,
#   '% Change': '1.007%',
#   'Market Cap': '14469716950.00',
#   'Country': 'United States',
#   'IPO Year': '2007',
#   'Volume': 710407,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Military/Government/Technical',
#   'id': 'ACM'},
#  {'Symbol': 'ACMR',
#   'Name': 'ACM Research Inc. Class A Common Stock',
#   'Last Sale': '$23.73',
#   'Net Change': -0.6,
#   '% Change': '-2.466%',
#   'Market Cap': '1515504680.00',
#   'Country': 'United States',
#   'IPO Year': '2017',
#   'Volume': 1086459,
#   'Sector': 'Technology',
#   'Industry': 'Industrial Machinery/Components',
#   'id': 'ACMR'},
#  {'Symbol': 'ACN',
#   'Name': 'Accenture plc Class A Ordinary Shares (Ireland)',
#   'Last Sale': '$317.69',
#   'Net Change': -5.52,
#   '% Change': '-1.708%',
#   'Market Cap': '215608664534.00',
#   'Country': 'Ireland',
#   'IPO Year': '2001',
#   'Volume': 3967391,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Business Services',
#   'id': 'ACN'},
#  {'Symbol': 'ACNB',
#   'Name': 'ACNB Corporation Common Stock',
#   'Last Sale': '$44.00',
#   'Net Change': -0.17,
#   '% Change': '-0.385%',
#   'Market Cap': '460842184.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 20395,
#   'Sector': 'Finance',
#   'Industry': 'Major Banks',
#   'id': 'ACNB'},
#  {'Symbol': 'ACNT',
#   'Name': 'Ascent Industries Co. Common Stock',
#   'Last Sale': '$12.39',
#   'Net Change': 0.41,
#   '% Change': '3.422%',
#   'Market Cap': '124020109.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 699881,
#   'Sector': 'Industrials',
#   'Industry': 'Steel/Iron Ore',
#   'id': 'ACNT'},
#  {'Symbol': 'ACOG',
#   'Name': 'Alpha Cognition Inc. Common Stock',
#   'Last Sale': '$8.65',
#   'Net Change': 1.84,
#   '% Change': '27.019%',
#   'Market Cap': '138571158.00',
#   'Country': 'Canada',
#   'IPO Year': '',
#   'Volume': 669633,
#   'Sector': '',
#   'Industry': '',
#   'id': 'ACOG'},
#  {'Symbol': 'ACON',
#   'Name': 'Aclarion Inc. Common Stock',
#   'Last Sale': '$6.94',
#   'Net Change': 0.04,
#   '% Change': '0.58%',
#   'Market Cap': '4041655.00',
#   'Country': 'United States',
#   'IPO Year': '2022',
#   'Volume': 12332,
#   'Sector': 'Health Care',
#   'Industry': 'Medical Specialities',
#   'id': 'ACON'},
#  {'Symbol': 'ACONW',
#   'Name': 'Aclarion Inc. Warrant',
#   'Last Sale': '$0.0369',
#   'Net Change': 0.0078,
#   '% Change': '26.804%',
#   'Market Cap': '21489.00',
#   'Country': 'United States',
#   'IPO Year': '2022',
#   'Volume': 9322,
#   'Sector': 'Health Care',
#   'Industry': 'Medical Specialities',
#   'id': 'ACONW'},
#  {'Symbol': 'ACP',
#   'Name': 'abrdn Income Credit Strategies Fund Common Shares',
#   'Last Sale': '$5.88',
#   'Net Change': -0.03,
#   '% Change': '-0.508%',
#   'Market Cap': '0.00',
#   'Country': 'United States',
#   'IPO Year': '2011',
#   'Volume': 427640,
#   'Sector': 'Finance',
#   'Industry': 'Investment Managers',
#   'id': 'ACP'},
#  {'Symbol': 'ACP^A',
#   'Name': 'abrdn Income Credit Strategies Fund 5.250% Series A Perpetual Preferred Stock',
#   'Last Sale': '$21.595',
#   'Net Change': 0.445,
#   '% Change': '2.104%',
#   'Market Cap': '',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 980,
#   'Sector': '',
#   'Industry': '',
#   'id': 'ACP_A'},
#  {'Symbol': 'ACR',
#   'Name': 'ACRES Commercial Realty Corp. Common Stock',
#   'Last Sale': '$18.90',
#   'Net Change': 0.13,
#   '% Change': '0.693%',
#   'Market Cap': '139750267.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 25541,
#   'Sector': 'Real Estate',
#   'Industry': 'Real Estate Investment Trusts',
#   'id': 'ACR'},
#  {'Symbol': 'ACR^C',
#   'Name': 'ACRES Commercial Realty Corp. 8.625% Fixed-to-Floating Series C Cumulative Redeemable Preferred Stock ',
#   'Last Sale': '$24.90',
#   'Net Change': -0.02,
#   '% Change': '-0.08%',
#   'Market Cap': '',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 10400,
#   'Sector': '',
#   'Industry': '',
#   'id': 'ACR_C'},
#  {'Symbol': 'ACR^D',
#   'Name': 'ACRES Commercial Realty Corp. 7.875% Series D Cumulative Redeemable Preferred Stock',
#   'Last Sale': '$20.99',
#   'Net Change': 0.0,
#   '% Change': '0.00%',
#   'Market Cap': '',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 3539,
#   'Sector': '',
#   'Industry': '',
#   'id': 'ACR_D'},
#  {'Symbol': 'ACRE',
#   'Name': 'Ares Commercial Real Estate Corporation Common Stock',
#   'Last Sale': '$4.82',
#   'Net Change': 0.02,
#   '% Change': '0.417%',
#   'Market Cap': '265125801.00',
#   'Country': 'United States',
#   'IPO Year': '2012',
#   'Volume': 403194,
#   'Sector': 'Real Estate',
#   'Industry': 'Real Estate Investment Trusts',
#   'id': 'ACRE'},
#  {'Symbol': 'ACRS',
#   'Name': 'Aclaris Therapeutics Inc. Common Stock',
#   'Last Sale': '$1.31',
#   'Net Change': 0.09,
#   '% Change': '7.377%',
#   'Market Cap': '141848423.00',
#   'Country': 'United States',
#   'IPO Year': '2015',
#   'Volume': 491151,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'ACRS'},
#  {'Symbol': 'ACRV',
#   'Name': 'Acrivon Therapeutics Inc. Common Stock',
#   'Last Sale': '$1.15',
#   'Net Change': 0.05,
#   '% Change': '4.545%',
#   'Market Cap': '36054202.00',
#   'Country': 'United States',
#   'IPO Year': '2022',
#   'Volume': 1605471,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'ACRV'},
#  {'Symbol': 'ACT',
#   'Name': 'Enact Holdings Inc. Common Stock',
#   'Last Sale': '$36.67',
#   'Net Change': 0.43,
#   '% Change': '1.187%',
#   'Market Cap': '5502930268.00',
#   'Country': 'United States',
#   'IPO Year': '2021',
#   'Volume': 719879,
#   'Sector': 'Finance',
#   'Industry': 'Specialty Insurers',
#   'id': 'ACT'},
#  {'Symbol': 'ACTG',
#   'Name': 'Acacia Research Corporation (Acacia Tech) Common Stock',
#   'Last Sale': '$3.72',
#   'Net Change': 0.01,
#   '% Change': '0.27%',
#   'Market Cap': '357758731.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 216075,
#   'Sector': 'Miscellaneous',
#   'Industry': 'Multi-Sector Companies',
#   'id': 'ACTG'},
#  {'Symbol': 'ACTU',
#   'Name': 'Actuate Therapeutics Inc. Common stock',
#   'Last Sale': '$10.55',
#   'Net Change': 0.79,
#   '% Change': '8.094%',
#   'Market Cap': '206058760.00',
#   'Country': 'United States',
#   'IPO Year': '2024',
#   'Volume': 63714,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'ACTU'},
#  {'Symbol': 'ACU',
#   'Name': 'Acme United Corporation. Common Stock',
#   'Last Sale': '$39.81',
#   'Net Change': 0.33,
#   '% Change': '0.836%',
#   'Market Cap': '150907329.00',
#   'Country': 'United States',
#   'IPO Year': '1988',
#   'Volume': 23897,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Industrial Machinery/Components',
#   'id': 'ACU'},
#  {'Symbol': 'ACV',
#   'Name': 'Virtus Diversified Income & Convertible Fund Common Shares of Beneficial Interest',
#   'Last Sale': '$21.78',
#   'Net Change': -0.02,
#   '% Change': '-0.092%',
#   'Market Cap': '225705138.00',
#   'Country': 'United States',
#   'IPO Year': '2015',
#   'Volume': 28257,
#   'Sector': 'Finance',
#   'Industry': 'Finance/Investors Services',
#   'id': 'ACV'},
#  {'Symbol': 'ACVA',
#   'Name': 'ACV Auctions Inc. Class A Common Stock',
#   'Last Sale': '$17.04',
#   'Net Change': 0.11,
#   '% Change': '0.65%',
#   'Market Cap': '2914944090.00',
#   'Country': 'United States',
#   'IPO Year': '2025',
#   'Volume': 2015890,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Business Services',
#   'id': 'ACVA'},
#  {'Symbol': 'ACXP',
#   'Name': 'Acurx Pharmaceuticals Inc. Common Stock',
#   'Last Sale': '$0.387',
#   'Net Change': 0.0139,
#   '% Change': '3.726%',
#   'Market Cap': '9087382.00',
#   'Country': 'United States',
#   'IPO Year': '2021',
#   'Volume': 283708,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'ACXP'},
#  {'Symbol': 'ADAG',
#   'Name': 'Adagene Inc. American Depositary Shares',
#   'Last Sale': '$1.77',
#   'Net Change': 0.0,
#   '% Change': '0.00%',
#   'Market Cap': '104229891.00',
#   'Country': 'China',
#   'IPO Year': '2021',
#   'Volume': 5030,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'ADAG'},
#  {'Symbol': 'ADAP',
#   'Name': 'Adaptimmune Therapeutics plc American Depositary Shares',
#   'Last Sale': '$0.2779',
#   'Net Change': 0.0132,
#   '% Change': '4.987%',
#   'Market Cap': '441947023.00',
#   'Country': 'United Kingdom',
#   'IPO Year': '2015',
#   'Volume': 415906,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Biological Products (No Diagnostic Substances)',
#   'id': 'ADAP'},
#  {'Symbol': 'ADBE',
#   'Name': 'Adobe Inc. Common Stock',
#   'Last Sale': '$417.125',
#   'Net Change': 12.435,
#   '% Change': '3.073%',
#   'Market Cap': '177945525000.00',
#   'Country': 'United States',
#   'IPO Year': '1986',
#   'Volume': 5387306,
#   'Sector': 'Technology',
#   'Industry': 'Computer Software: Prepackaged Software',
#   'id': 'ADBE'},
#  {'Symbol': 'ADC',
#   'Name': 'Agree Realty Corporation Common Stock',
#   'Last Sale': '$74.92',
#   'Net Change': 1.0,
#   '% Change': '1.353%',
#   'Market Cap': '8242589616.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 864307,
#   'Sector': 'Real Estate',
#   'Industry': 'Real Estate Investment Trusts',
#   'id': 'ADC'},
#  {'Symbol': 'ADC^A',
#   'Name': 'Agree Realty Corporation Depositary Shares each representing 1/1000th of a 4.250% Series A Cumulative Redeemable Preferred Stock',
#   'Last Sale': '$17.57',
#   'Net Change': -0.06,
#   '% Change': '-0.34%',
#   'Market Cap': '',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 4184,
#   'Sector': '',
#   'Industry': '',
#   'id': 'ADC_A'},
#  {'Symbol': 'ADCT',
#   'Name': 'ADC Therapeutics SA Common Shares',
#   'Last Sale': '$1.89',
#   'Net Change': 0.2,
#   '% Change': '11.834%',
#   'Market Cap': '187268454.00',
#   'Country': 'Switzerland',
#   'IPO Year': '2020',
#   'Volume': 427011,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'ADCT'},
#  {'Symbol': 'ADD',
#   'Name': 'Color Star Technology Co. Ltd. Class A Ordinary Shares',
#   'Last Sale': '$0.92',
#   'Net Change': 0.0192,
#   '% Change': '2.131%',
#   'Market Cap': '565466.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 340985,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Engineering & Construction',
#   'id': 'ADD'},
#  {'Symbol': 'ADEA',
#   'Name': 'Adeia Inc. Common Stock',
#   'Last Sale': '$13.58',
#   'Net Change': -0.17,
#   '% Change': '-1.236%',
#   'Market Cap': '1473427990.00',
#   'Country': 'United States',
#   'IPO Year': '2003',
#   'Volume': 562077,
#   'Sector': 'Technology',
#   'Industry': 'Computer Software: Prepackaged Software',
#   'id': 'ADEA'},
#  {'Symbol': 'ADGM',
#   'Name': 'Adagio Medical Holdings Inc Common Stock',
#   'Last Sale': '$1.18',
#   'Net Change': -0.04,
#   '% Change': '-3.279%',
#   'Market Cap': '18150247.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 64057,
#   'Sector': 'Health Care',
#   'Industry': 'Medical/Dental Instruments',
#   'id': 'ADGM'},
#  {'Symbol': 'ADI',
#   'Name': 'Analog Devices Inc. Common Stock',
#   'Last Sale': '$227.11',
#   'Net Change': -0.01,
#   '% Change': '-0.004%',
#   'Market Cap': '112641219054.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 3617877,
#   'Sector': 'Technology',
#   'Industry': 'Semiconductors',
#   'id': 'ADI'},
#  {'Symbol': 'ADIL',
#   'Name': 'Adial Pharmaceuticals Inc Common Stock',
#   'Last Sale': '$0.6578',
#   'Net Change': -0.0022,
#   '% Change': '-0.333%',
#   'Market Cap': '4324764.00',
#   'Country': 'United States',
#   'IPO Year': '2018',
#   'Volume': 81050,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'ADIL'},
#  {'Symbol': 'ADM',
#   'Name': 'Archer-Daniels-Midland Company Common Stock',
#   'Last Sale': '$50.13',
#   'Net Change': 1.27,
#   '% Change': '2.599%',
#   'Market Cap': '24084959252.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 3226971,
#   'Sector': 'Consumer Staples',
#   'Industry': 'Packaged Foods',
#   'id': 'ADM'},
#  {'Symbol': 'ADMA',
#   'Name': 'ADMA Biologics Inc Common Stock',
#   'Last Sale': '$19.69',
#   'Net Change': 0.49,
#   '% Change': '2.552%',
#   'Market Cap': '4700677304.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 2525851,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Biological Products (No Diagnostic Substances)',
#   'id': 'ADMA'},
#  {'Symbol': 'ADN',
#   'Name': 'Advent Technologies Holdings Inc. Class A Common Stock',
#   'Last Sale': '$2.40',
#   'Net Change': -0.06,
#   '% Change': '-2.439%',
#   'Market Cap': '6327619.00',
#   'Country': 'United States',
#   'IPO Year': '2018',
#   'Volume': 14161,
#   'Sector': 'Miscellaneous',
#   'Industry': 'Industrial Machinery/Components',
#   'id': 'ADN'},
#  {'Symbol': 'ADNT',
#   'Name': 'Adient plc Ordinary Shares ',
#   'Last Sale': '$15.82',
#   'Net Change': 0.33,
#   '% Change': '2.13%',
#   'Market Cap': '1329143308.00',
#   'Country': 'United States',
#   'IPO Year': '2016',
#   'Volume': 1388832,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Auto Parts:O.E.M.',
#   'id': 'ADNT'},
#  {'Symbol': 'ADNWW',
#   'Name': 'Advent Technologies Holdings Inc. Warrant',
#   'Last Sale': '$0.0083',
#   'Net Change': 0.0009,
#   '% Change': '12.162%',
#   'Market Cap': '21883.00',
#   'Country': 'United States',
#   'IPO Year': '2018',
#   'Volume': 13956,
#   'Sector': 'Miscellaneous',
#   'Industry': 'Industrial Machinery/Components',
#   'id': 'ADNWW'},
#  {'Symbol': 'ADP',
#   'Name': 'Automatic Data Processing Inc. Common Stock',
#   'Last Sale': '$319.37',
#   'Net Change': 3.52,
#   '% Change': '1.114%',
#   'Market Cap': '129639548348.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 1488982,
#   'Sector': 'Technology',
#   'Industry': 'EDP Services',
#   'id': 'ADP'},
#  {'Symbol': 'ADPT',
#   'Name': 'Adaptive Biotechnologies Corporation Common Stock',
#   'Last Sale': '$9.05',
#   'Net Change': 0.14,
#   '% Change': '1.571%',
#   'Market Cap': '1374846334.00',
#   'Country': 'United States',
#   'IPO Year': '2019',
#   'Volume': 963814,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Biological Products (No Diagnostic Substances)',
#   'id': 'ADPT'},
#  {'Symbol': 'ADSE',
#   'Name': 'ADS-TEC ENERGY PLC Ordinary Shares',
#   'Last Sale': '$12.29',
#   'Net Change': 0.21,
#   '% Change': '1.738%',
#   'Market Cap': '673987496.00',
#   'Country': 'Ireland',
#   'IPO Year': '',
#   'Volume': 110097,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Industrial Specialties',
#   'id': 'ADSE'},
#  {'Symbol': 'ADSEW',
#   'Name': 'ADS-TEC ENERGY PLC Warrant',
#   'Last Sale': '$2.0495',
#   'Net Change': 0.4545,
#   '% Change': '28.495%',
#   'Market Cap': '112395230.00',
#   'Country': 'Ireland',
#   'IPO Year': '',
#   'Volume': 91801,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Industrial Specialties',
#   'id': 'ADSEW'},
#  {'Symbol': 'ADSK',
#   'Name': 'Autodesk Inc. Common Stock',
#   'Last Sale': '$298.08',
#   'Net Change': 2.3,
#   '% Change': '0.778%',
#   'Market Cap': '64087200000.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 1901593,
#   'Sector': 'Technology',
#   'Industry': 'Computer Software: Prepackaged Software',
#   'id': 'ADSK'},
#  {'Symbol': 'ADT',
#   'Name': 'ADT Inc. Common Stock',
#   'Last Sale': '$8.59',
#   'Net Change': 0.12,
#   '% Change': '1.417%',
#   'Market Cap': '7185624980.00',
#   'Country': 'United States',
#   'IPO Year': '2018',
#   'Volume': 16531191,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Diversified Commercial Services',
#   'id': 'ADT'},
#  {'Symbol': 'ADTN',
#   'Name': 'ADTRAN Holdings Inc. Common Stock',
#   'Last Sale': '$8.13',
#   'Net Change': -0.06,
#   '% Change': '-0.733%',
#   'Market Cap': '649262068.00',
#   'Country': 'United States',
#   'IPO Year': '1994',
#   'Volume': 530261,
#   'Sector': 'Utilities',
#   'Industry': 'Telecommunications Equipment',
#   'id': 'ADTN'},
#  {'Symbol': 'ADTX',
#   'Name': 'Aditxt Inc. Common Stock',
#   'Last Sale': '$1.66',
#   'Net Change': 0.05,
#   '% Change': '3.106%',
#   'Market Cap': '1924272.00',
#   'Country': 'United States',
#   'IPO Year': '2020',
#   'Volume': 67594,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'ADTX'},
#  {'Symbol': 'ADUR',
#   'Name': 'Aduro Clean Technologies Inc. Common Stock',
#   'Last Sale': '$6.45',
#   'Net Change': 0.43,
#   '% Change': '7.143%',
#   'Market Cap': '186467617.00',
#   'Country': 'Canada',
#   'IPO Year': '',
#   'Volume': 138070,
#   'Sector': '',
#   'Industry': '',
#   'id': 'ADUR'},
#  {'Symbol': 'ADUS',
#   'Name': 'Addus HomeCare Corporation Common Stock',
#   'Last Sale': '$111.63',
#   'Net Change': 1.73,
#   '% Change': '1.574%',
#   'Market Cap': '2053895887.00',
#   'Country': 'United States',
#   'IPO Year': '2009',
#   'Volume': 158285,
#   'Sector': 'Health Care',
#   'Industry': 'Medical/Nursing Services',
#   'id': 'ADUS'},
#  {'Symbol': 'ADV',
#   'Name': 'Advantage Solutions Inc. Class A Common Stock',
#   'Last Sale': '$1.26',
#   'Net Change': 0.17,
#   '% Change': '15.596%',
#   'Market Cap': '408633120.00',
#   'Country': 'United States',
#   'IPO Year': '2019',
#   'Volume': 1406542,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Business Services',
#   'id': 'ADV'},
#  {'Symbol': 'ADVB',
#   'Name': 'Advanced Biomed Inc. Common Stock',
#   'Last Sale': '$1.27',
#   'Net Change': 0.11,
#   '% Change': '9.483%',
#   'Market Cap': '27482800.00',
#   'Country': 'Taiwan',
#   'IPO Year': '2025',
#   'Volume': 21435,
#   'Sector': 'Health Care',
#   'Industry': 'Medical Specialities',
#   'id': 'ADVB'},
#  {'Symbol': 'ADVM',
#   'Name': 'Adverum Biotechnologies Inc. Common Stock',
#   'Last Sale': '$2.115',
#   'Net Change': 0.065,
#   '% Change': '3.171%',
#   'Market Cap': '44183492.00',
#   'Country': 'United States',
#   'IPO Year': '2014',
#   'Volume': 391743,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Biological Products (No Diagnostic Substances)',
#   'id': 'ADVM'},
#  {'Symbol': 'ADVWW',
#   'Name': 'Advantage Solutions Inc. Warrant',
#   'Last Sale': '$0.0129',
#   'Net Change': 0.0004,
#   '% Change': '3.20%',
#   'Market Cap': '4183625.00',
#   'Country': 'United States',
#   'IPO Year': '2019',
#   'Volume': 551,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Business Services',
#   'id': 'ADVWW'},
#  {'Symbol': 'ADX',
#   'Name': 'Adams Diversified Equity Fund Inc.',
#   'Last Sale': '$20.40',
#   'Net Change': 0.27,
#   '% Change': '1.341%',
#   'Market Cap': '0.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 219000,
#   'Sector': 'Finance',
#   'Industry': 'Investment Managers',
#   'id': 'ADX'},
#  {'Symbol': 'ADXN',
#   'Name': 'Addex Therapeutics Ltd American Depositary Shares',
#   'Last Sale': '$8.50',
#   'Net Change': 0.38,
#   '% Change': '4.68%',
#   'Market Cap': '8868008.00',
#   'Country': 'Switzerland',
#   'IPO Year': '',
#   'Volume': 674,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'ADXN'},
#  {'Symbol': 'AEE',
#   'Name': 'Ameren Corporation Common Stock',
#   'Last Sale': '$98.02',
#   'Net Change': 1.2,
#   '% Change': '1.239%',
#   'Market Cap': '26492739444.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 1254624,
#   'Sector': 'Utilities',
#   'Industry': 'Power Generation',
#   'id': 'AEE'},
#  {'Symbol': 'AEF',
#   'Name': 'abrdn Emerging Markets ex-China Fund Inc. Common Stock',
#   'Last Sale': '$5.46',
#   'Net Change': 0.01,
#   '% Change': '0.183%',
#   'Market Cap': '586199250.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 124077,
#   'Sector': 'Finance',
#   'Industry': 'Finance/Investors Services',
#   'id': 'AEF'},
#  {'Symbol': 'AEFC',
#   'Name': 'Aegon Funding Company LLC 5.10% Subordinated Notes due 2049',
#   'Last Sale': '$20.05',
#   'Net Change': 0.19,
#   '% Change': '0.957%',
#   'Market Cap': '0.00',
#   'Country': 'United States',
#   'IPO Year': '2019',
#   'Volume': 40781,
#   'Sector': '',
#   'Industry': '',
#   'id': 'AEFC'},
#  {'Symbol': 'AEG',
#   'Name': 'Aegon Ltd. New York Registry Shares',
#   'Last Sale': '$6.91',
#   'Net Change': -0.06,
#   '% Change': '-0.861%',
#   'Market Cap': '13862739953.00',
#   'Country': 'Netherlands',
#   'IPO Year': '',
#   'Volume': 14529283,
#   'Sector': 'Finance',
#   'Industry': 'Life Insurance',
#   'id': 'AEG'},
#  {'Symbol': 'AEHL',
#   'Name': 'Antelope Enterprise Holdings Limited Class A Ordinary Shares',
#   'Last Sale': '$2.82',
#   'Net Change': 0.13,
#   '% Change': '4.833%',
#   'Market Cap': '9640982.00',
#   'Country': 'China',
#   'IPO Year': '',
#   'Volume': 145400,
#   'Sector': 'Industrials',
#   'Industry': 'Building Materials',
#   'id': 'AEHL'},
#  {'Symbol': 'AEHR',
#   'Name': 'Aehr Test Systems Common Stock',
#   'Last Sale': '$9.29',
#   'Net Change': 0.0,
#   '% Change': '0.00%',
#   'Market Cap': '276576399.00',
#   'Country': 'United States',
#   'IPO Year': '1997',
#   'Volume': 491592,
#   'Sector': 'Industrials',
#   'Industry': 'Electrical Products',
#   'id': 'AEHR'},
#  {'Symbol': 'AEI',
#   'Name': 'Alset Inc. Common Stock (TX)',
#   'Last Sale': '$0.9482',
#   'Net Change': -0.0118,
#   '% Change': '-1.229%',
#   'Market Cap': '10179040.00',
#   'Country': 'United States',
#   'IPO Year': '2020',
#   'Volume': 28587,
#   'Sector': 'Finance',
#   'Industry': 'Real Estate',
#   'id': 'AEI'},
#  {'Symbol': 'AEIS',
#   'Name': 'Advanced Energy Industries Inc. Common Stock',
#   'Last Sale': '$118.15',
#   'Net Change': -0.61,
#   '% Change': '-0.514%',
#   'Market Cap': '4448983620.00',
#   'Country': 'United States',
#   'IPO Year': '1995',
#   'Volume': 219338,
#   'Sector': 'Technology',
#   'Industry': 'Industrial Machinery/Components',
#   'id': 'AEIS'},
#  {'Symbol': 'AEM',
#   'Name': 'Agnico Eagle Mines Limited Common Stock',
#   'Last Sale': '$106.45',
#   'Net Change': -0.06,
#   '% Change': '-0.056%',
#   'Market Cap': '53559687422.00',
#   'Country': 'Canada',
#   'IPO Year': '',
#   'Volume': 3865227,
#   'Sector': 'Basic Materials',
#   'Industry': 'Precious Metals',
#   'id': 'AEM'},
#  {'Symbol': 'AEMD',
#   'Name': 'Aethlon Medical Inc. Common Stock',
#   'Last Sale': '$0.4027',
#   'Net Change': 0.0027,
#   '% Change': '0.675%',
#   'Market Cap': '5821873.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 152032,
#   'Sector': 'Health Care',
#   'Industry': 'Medical/Dental Instruments',
#   'id': 'AEMD'},
#  {'Symbol': 'AENT',
#   'Name': 'Alliance Entertainment Holding Corporation Class A Common Stock',
#   'Last Sale': '$2.92',
#   'Net Change': 0.34,
#   '% Change': '13.178%',
#   'Market Cap': '148795520.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 70734,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Durable Goods',
#   'id': 'AENT'},
#  {'Symbol': 'AENTW',
#   'Name': 'Alliance Entertainment Holding Corporation Warrants',
#   'Last Sale': '$0.18',
#   'Net Change': 0.0054,
#   '% Change': '3.093%',
#   'Market Cap': '9172327.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 29103,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Durable Goods',
#   'id': 'AENTW'},
#  {'Symbol': 'AEO',
#   'Name': 'American Eagle Outfitters Inc. Common Stock',
#   'Last Sale': '$12.36',
#   'Net Change': 0.38,
#   '% Change': '3.172%',
#   'Market Cap': '2132274301.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 7086168,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Clothing/Shoe/Accessory Stores',
#   'id': 'AEO'},
#  {'Symbol': 'AEON',
#   'Name': 'AEON Biopharma Inc. Class A Common Stock',
#   'Last Sale': '$0.50',
#   'Net Change': 0.0069,
#   '% Change': '1.399%',
#   'Market Cap': '5266401.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 833350,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'AEON'},
#  {'Symbol': 'AEP',
#   'Name': 'American Electric Power Company Inc. Common Stock',
#   'Last Sale': '$103.04',
#   'Net Change': 1.43,
#   '% Change': '1.407%',
#   'Market Cap': '55043455479.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 2868294,
#   'Sector': 'Utilities',
#   'Industry': 'Electric Utilities: Central',
#   'id': 'AEP'},
#  {'Symbol': 'AER',
#   'Name': 'AerCap Holdings N.V. Ordinary Shares',
#   'Last Sale': '$113.07',
#   'Net Change': -0.52,
#   '% Change': '-0.458%',
#   'Market Cap': '21119579251.00',
#   'Country': 'Netherlands',
#   'IPO Year': '2006',
#   'Volume': 1696339,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Diversified Commercial Services',
#   'id': 'AER'},
#  {'Symbol': 'AERT',
#   'Name': 'Aeries Technology Inc. Class A Ordinary Share',
#   'Last Sale': '$0.66',
#   'Net Change': 0.005,
#   '% Change': '0.763%',
#   'Market Cap': '29408278.00',
#   'Country': 'United States',
#   'IPO Year': '2021',
#   'Volume': 15255,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Professional Services',
#   'id': 'AERT'},
#  {'Symbol': 'AERTW',
#   'Name': 'Aeries Technology Inc. Warrant',
#   'Last Sale': '$0.012',
#   'Net Change': -0.0042,
#   '% Change': '-25.926%',
#   'Market Cap': '534696.00',
#   'Country': 'United States',
#   'IPO Year': '2021',
#   'Volume': 42666,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Professional Services',
#   'id': 'AERTW'},
#  {'Symbol': 'AES',
#   'Name': 'The AES Corporation Common Stock',
#   'Last Sale': '$12.21',
#   'Net Change': -0.19,
#   '% Change': '-1.532%',
#   'Market Cap': '8692577571.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 13450155,
#   'Sector': 'Utilities',
#   'Industry': 'Electric Utilities: Central',
#   'id': 'AES'},
#  {'Symbol': 'AESI',
#   'Name': 'Atlas Energy Solutions Inc. Common Stock',
#   'Last Sale': '$13.48',
#   'Net Change': 0.71,
#   '% Change': '5.56%',
#   'Market Cap': '1666414221.00',
# ...
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'BOLT'},
#  {'Symbol': 'BON',
#   'Name': 'Bon Natural Life Limited Class A Ordinary Shares',
#   'Last Sale': '$0.0638',
#   'Net Change': 0.0117,
#   '% Change': '22.457%',
#   'Market Cap': '253322.00',
#   'Country': 'China',
#   'IPO Year': '2021',
#   'Volume': 297949781,
#   'Sector': 'Health Care',
#   'Industry': ' Medicinal Chemicals and Botanical Products ',
#   'id': 'BON'},
#  {'Symbol': 'BOOM',
#   'Name': 'DMC Global Inc. Common Stock',
#   'Last Sale': '$6.93',
#   'Net Change': 0.07,
#   '% Change': '1.02%',
#   'Market Cap': '142000703.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 222228,
#   'Sector': 'Industrials',
#   'Industry': 'Industrial Specialties',
#   'id': 'BOOM'},
#  {'Symbol': 'BOOT',
#   'Name': 'Boot Barn Holdings Inc. Common Stock',
#   'Last Sale': '$156.71',
#   'Net Change': 1.74,
#   '% Change': '1.123%',
#   'Market Cap': '4794224956.00',
#   'Country': 'United States',
#   'IPO Year': '2014',
#   'Volume': 1081491,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Clothing/Shoe/Accessory Stores',
#   'id': 'BOOT'},
#  {'Symbol': 'BORR',
#   'Name': 'Borr Drilling Limited Common Shares',
#   'Last Sale': '$1.78',
#   'Net Change': -0.04,
#   '% Change': '-2.198%',
#   'Market Cap': '435969741.00',
#   'Country': '',
#   'IPO Year': '2019',
#   'Volume': 4153361,
#   'Sector': 'Energy',
#   'Industry': 'Oil & Gas Production',
#   'id': 'BORR'},
#  {'Symbol': 'BOSC',
#   'Name': 'B.O.S. Better Online Solutions Common Stock',
#   'Last Sale': '$3.905',
#   'Net Change': 0.105,
#   '% Change': '2.763%',
#   'Market Cap': '23131498.00',
#   'Country': 'Israel',
#   'IPO Year': '',
#   'Volume': 107330,
#   'Sector': 'Telecommunications',
#   'Industry': 'Computer Communications Equipment',
#   'id': 'BOSC'},
#  {'Symbol': 'BOTJ',
#   'Name': 'Bank of the James Financial Group Inc. Common Stock',
#   'Last Sale': '$14.02',
#   'Net Change': -0.17,
#   '% Change': '-1.198%',
#   'Market Cap': '63697599.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 2141,
#   'Sector': 'Finance',
#   'Industry': 'Major Banks',
#   'id': 'BOTJ'},
#  {'Symbol': 'BOW',
#   'Name': 'Bowhead Specialty Holdings Inc. Common Stock',
#   'Last Sale': '$38.41',
#   'Net Change': -0.4,
#   '% Change': '-1.031%',
#   'Market Cap': '1254573654.00',
#   'Country': 'United States',
#   'IPO Year': '2024',
#   'Volume': 235314,
#   'Sector': 'Finance',
#   'Industry': 'Property-Casualty Insurers',
#   'id': 'BOW'},
#  {'Symbol': 'BOWN',
#   'Name': 'Bowen Acquisition Corp Ordinary Shares',
#   'Last Sale': '$11.50',
#   'Net Change': -0.87,
#   '% Change': '-7.033%',
#   'Market Cap': '0.00',
#   'Country': 'United States',
#   'IPO Year': '2023',
#   'Volume': 654,
#   'Sector': '',
#   'Industry': '',
#   'id': 'BOWN'},
#  {'Symbol': 'BOWNR',
#   'Name': 'Bowen Acquisition Corp Rights',
#   'Last Sale': '$0.2194',
#   'Net Change': 0.0234,
#   '% Change': '11.939%',
#   'Market Cap': '0.00',
#   'Country': 'United States',
#   'IPO Year': '2023',
#   'Volume': 4688,
#   'Sector': '',
#   'Industry': '',
#   'id': 'BOWNR'},
#  {'Symbol': 'BOWNU',
#   'Name': 'Bowen Acquisition Corp Unit',
#   'Last Sale': '$10.50',
#   'Net Change': 0.0,
#   '% Change': '0.00%',
#   'Market Cap': '0.00',
#   'Country': 'United States',
#   'IPO Year': '2023',
#   'Volume': 5,
#   'Sector': '',
#   'Industry': '',
#   'id': 'BOWNU'},
#  {'Symbol': 'BOX',
#   'Name': 'Box Inc. Class A Common Stock',
#   'Last Sale': '$32.28',
#   'Net Change': 0.03,
#   '% Change': '0.093%',
#   'Market Cap': '4641515441.00',
#   'Country': 'United States',
#   'IPO Year': '2015',
#   'Volume': 1429763,
#   'Sector': 'Technology',
#   'Industry': 'Computer Software: Prepackaged Software',
#   'id': 'BOX'},
#  {'Symbol': 'BOXL',
#   'Name': 'Boxlight Corporation Class A Common Stock',
#   'Last Sale': '$1.715',
#   'Net Change': 0.095,
#   '% Change': '5.864%',
#   'Market Cap': '3821857.00',
#   'Country': 'United States',
#   'IPO Year': '2017',
#   'Volume': 19194,
#   'Sector': 'Real Estate',
#   'Industry': 'Other Consumer Services',
#   'id': 'BOXL'},
#  {'Symbol': 'BP',
#   'Name': 'BP p.l.c. Common Stock',
#   'Last Sale': '$29.76',
#   'Net Change': -0.35,
#   '% Change': '-1.162%',
#   'Market Cap': '79104805302.00',
#   'Country': 'United Kingdom',
#   'IPO Year': '',
#   'Volume': 6928989,
#   'Sector': 'Energy',
#   'Industry': 'Integrated oil Companies',
#   'id': 'BP'},
#  {'Symbol': 'BPMC',
#   'Name': 'Blueprint Medicines Corporation Common Stock',
#   'Last Sale': '$101.69',
#   'Net Change': 2.2,
#   '% Change': '2.211%',
#   'Market Cap': '6567360155.00',
#   'Country': 'United States',
#   'IPO Year': '2015',
#   'Volume': 581639,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'BPMC'},
#  {'Symbol': 'BPOP',
#   'Name': 'Popular Inc. Common Stock',
#   'Last Sale': '$104.52',
#   'Net Change': -0.27,
#   '% Change': '-0.258%',
#   'Market Cap': '7160746098.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 464570,
#   'Sector': 'Finance',
#   'Industry': 'Major Banks',
#   'id': 'BPOP'},
#  {'Symbol': 'BPOPM',
#   'Name': 'Popular Inc. Popular Capital Trust II - 6.125% Cumulative Monthly Income Trust Preferred Securities',
#   'Last Sale': '$25.58',
#   'Net Change': -0.06,
#   '% Change': '-0.234%',
#   'Market Cap': '1752505599.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 467,
#   'Sector': 'Finance',
#   'Industry': 'Major Banks',
#   'id': 'BPOPM'},
#  {'Symbol': 'BPRN',
#   'Name': 'Princeton Bancorp Inc. Common Stock (PA)',
#   'Last Sale': '$32.10',
#   'Net Change': -0.87,
#   '% Change': '-2.639%',
#   'Market Cap': '222425073.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 7618,
#   'Sector': 'Finance',
#   'Industry': 'Major Banks',
#   'id': 'BPRN'},
#  {'Symbol': 'BPT',
#   'Name': 'BP Prudhoe Bay Royalty Trust Common Stock',
#   'Last Sale': '$0.623',
#   'Net Change': -0.017,
#   '% Change': '-2.656%',
#   'Market Cap': '13332200.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 43990,
#   'Sector': 'Energy',
#   'Industry': 'Integrated oil Companies',
#   'id': 'BPT'},
#  {'Symbol': 'BPYPM',
#   'Name': 'Brookfield Property Partners L.P. 6.25% Class A Cumulative Redeemable Preferred Units Series 1',
#   'Last Sale': '$15.1501',
#   'Net Change': -0.0799,
#   '% Change': '-0.525%',
#   'Market Cap': '13655452492.00',
#   'Country': 'Bermuda',
#   'IPO Year': '',
#   'Volume': 8693,
#   'Sector': 'Finance',
#   'Industry': 'Real Estate',
#   'id': 'BPYPM'},
#  {'Symbol': 'BPYPN',
#   'Name': 'Brookfield Property Partners L.P. 5.750% Class A Cumulative Redeemable Perpetual Preferred Units Series 3',
#   'Last Sale': '$13.47',
#   'Net Change': -0.17,
#   '% Change': '-1.246%',
#   'Market Cap': '12141104354.00',
#   'Country': 'Bermuda',
#   'IPO Year': '',
#   'Volume': 16030,
#   'Sector': 'Finance',
#   'Industry': 'Real Estate',
#   'id': 'BPYPN'},
#  {'Symbol': 'BPYPO',
#   'Name': 'Brookfield Property Partners L.P. 6.375% Class A Cumulative Redeemable Perpetual Preferred Units Series 2',
#   'Last Sale': '$14.95',
#   'Net Change': -0.12,
#   '% Change': '-0.796%',
#   'Market Cap': '13475093548.00',
#   'Country': 'Bermuda',
#   'IPO Year': '',
#   'Volume': 6552,
#   'Sector': 'Finance',
#   'Industry': 'Real Estate',
#   'id': 'BPYPO'},
#  {'Symbol': 'BPYPP',
#   'Name': 'Brookfield Property Partners L.P. 6.50% Class A Cumulative Redeemable Perpetual Preferred Units',
#   'Last Sale': '$15.11',
#   'Net Change': 0.06,
#   '% Change': '0.399%',
#   'Market Cap': '13619308596.00',
#   'Country': 'Bermuda',
#   'IPO Year': '',
#   'Volume': 47220,
#   'Sector': 'Finance',
#   'Industry': 'Real Estate',
#   'id': 'BPYPP'},
#  {'Symbol': 'BQ',
#   'Name': 'Boqii Holding Limited American Depositary Shares (each representing one hundred fifty (150) Class A Ordinary Shares)',
#   'Last Sale': '$2.17',
#   'Net Change': -0.04,
#   '% Change': '-1.81%',
#   'Market Cap': '2325220.00',
#   'Country': '',
#   'IPO Year': '',
#   'Volume': 46531,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Other Specialty Stores',
#   'id': 'BQ'},
#  {'Symbol': 'BR',
#   'Name': 'Broadridge Financial Solutions Inc. Common Stock',
#   'Last Sale': '$241.21',
#   'Net Change': 0.89,
#   '% Change': '0.37%',
#   'Market Cap': '28333356362.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 475637,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Business Services',
#   'id': 'BR'},
#  {'Symbol': 'BRAG',
#   'Name': 'Bragg Gaming Group Inc. Common Shares',
#   'Last Sale': '$4.68',
#   'Net Change': 0.15,
#   '% Change': '3.311%',
#   'Market Cap': '116748572.00',
#   'Country': 'Canada',
#   'IPO Year': '',
#   'Volume': 63550,
#   'Sector': 'Technology',
#   'Industry': 'Office Equipment/Supplies/Services',
#   'id': 'BRAG'},
#  {'Symbol': 'BRBR',
#   'Name': 'BellRing Brands Inc. Common Stock ',
#   'Last Sale': '$65.89',
#   'Net Change': 1.62,
#   '% Change': '2.521%',
#   'Market Cap': '8367813354.00',
#   'Country': 'United States',
#   'IPO Year': '2022',
#   'Volume': 1923934,
#   'Sector': 'Consumer Staples',
#   'Industry': 'Packaged Foods',
#   'id': 'BRBR'},
#  {'Symbol': 'BRBS',
#   'Name': 'Blue Ridge Bankshares Inc. Common Stock',
#   'Last Sale': '$3.47',
#   'Net Change': -0.05,
#   '% Change': '-1.42%',
#   'Market Cap': '316387136.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 239703,
#   'Sector': 'Finance',
#   'Industry': 'Major Banks',
#   'id': 'BRBS'},
#  {'Symbol': 'BRC',
#   'Name': 'Brady Corporation Common Stock',
#   'Last Sale': '$71.52',
#   'Net Change': -4.72,
#   '% Change': '-6.191%',
#   'Market Cap': '3417241978.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 361401,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Miscellaneous manufacturing industries',
#   'id': 'BRC'},
#  {'Symbol': 'BRCC',
#   'Name': 'BRC Inc. Class A Common Stock',
#   'Last Sale': '$1.97',
#   'Net Change': 0.03,
#   '% Change': '1.546%',
#   'Market Cap': '420045445.00',
#   'Country': 'United States',
#   'IPO Year': '2022',
#   'Volume': 586462,
#   'Sector': 'Consumer Staples',
#   'Industry': 'Beverages (Production/Distribution)',
#   'id': 'BRCC'},
#  {'Symbol': 'BRDG',
#   'Name': 'Bridge Investment Group Holdings Inc. Class A Common Stock',
#   'Last Sale': '$10.11',
#   'Net Change': -0.01,
#   '% Change': '-0.099%',
#   'Market Cap': '1251383792.00',
#   'Country': 'United States',
#   'IPO Year': '2021',
#   'Volume': 273134,
#   'Sector': 'Finance',
#   'Industry': 'Investment Managers',
#   'id': 'BRDG'},
#  {'Symbol': 'BREA',
#   'Name': 'Brera Holdings PLC Class B Ordinary Shares',
#   'Last Sale': '$0.6705',
#   'Net Change': 0.0109,
#   '% Change': '1.653%',
#   'Market Cap': '8532113.00',
#   'Country': 'Ireland',
#   'IPO Year': '2023',
#   'Volume': 76391,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Services-Misc. Amusement & Recreation',
#   'id': 'BREA'},
#  {'Symbol': 'BRFH',
#   'Name': 'Barfresh Food Group Inc. Common Stock',
#   'Last Sale': '$2.48',
#   'Net Change': 0.08,
#   '% Change': '3.333%',
#   'Market Cap': '39481717.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 5341,
#   'Sector': 'Consumer Staples',
#   'Industry': 'Packaged Foods',
#   'id': 'BRFH'},
#  {'Symbol': 'BRFS',
#   'Name': 'BRF S.A.',
#   'Last Sale': '$3.61',
#   'Net Change': 0.02,
#   '% Change': '0.557%',
#   'Market Cap': '5775278271.00',
#   'Country': 'Brazil',
#   'IPO Year': '',
#   'Volume': 19837030,
#   'Sector': 'Consumer Staples',
#   'Industry': 'Meat/Poultry/Fish',
#   'id': 'BRFS'},
#  {'Symbol': 'BRIA',
#   'Name': 'BrilliA Inc Class A Ordinary Shares',
#   'Last Sale': '$2.53',
#   'Net Change': 0.04,
#   '% Change': '1.606%',
#   'Market Cap': '77481250.00',
#   'Country': '',
#   'IPO Year': '2024',
#   'Volume': 24957,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Apparel',
#   'id': 'BRIA'},
#  {'Symbol': 'BRID',
#   'Name': 'Bridgford Foods Corporation Common Stock',
#   'Last Sale': '$7.75',
#   'Net Change': -0.08,
#   '% Change': '-1.022%',
#   'Market Cap': '70345448.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 2803,
#   'Sector': 'Consumer Staples',
#   'Industry': 'Specialty Foods',
#   'id': 'BRID'},
#  {'Symbol': 'BRK/A',
#   'Name': 'Berkshire Hathaway Inc.',
#   'Last Sale': '$770660.00',
#   'Net Change': 11560.0,
#   '% Change': '1.523%',
#   'Market Cap': '1133543756840.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 370,
#   'Sector': '',
#   'Industry': '',
#   'id': 'BRK_A'},
#  {'Symbol': 'BRK/B',
#   'Name': 'Berkshire Hathaway Inc.',
#   'Last Sale': '$514.31',
#   'Net Change': 6.98,
#   '% Change': '1.376%',
#   'Market Cap': '1134728001219.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 4984399,
#   'Sector': '',
#   'Industry': '',
#   'id': 'BRK_B'},
#  {'Symbol': 'BRKL',
#   'Name': 'Brookline Bancorp Inc. Common Stock',
#   'Last Sale': '$11.04',
#   'Net Change': -0.07,
#   '% Change': '-0.63%',
#   'Market Cap': '983714839.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 404801,
#   'Sector': 'Finance',
#   'Industry': 'Savings Institutions',
#   'id': 'BRKL'},
#  {'Symbol': 'BRKR',
#   'Name': 'Bruker Corporation Common Stock',
#   'Last Sale': '$37.53',
#   'Net Change': 0.84,
#   '% Change': '2.289%',
#   'Market Cap': '5686988567.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 1786229,
#   'Sector': 'Industrials',
#   'Industry': 'Biotechnology: Laboratory Analytical Instruments',
#   'id': 'BRKR'},
#  {'Symbol': 'BRLS',
#   'Name': 'Borealis Foods Inc. Class A Common Shares',
#   'Last Sale': '$5.50',
#   'Net Change': -0.33,
#   '% Change': '-5.66%',
#   'Market Cap': '117583895.00',
#   'Country': 'Kazakhstan',
#   'IPO Year': '2021',
#   'Volume': 4403,
#   'Sector': 'Consumer Staples',
#   'Industry': 'Packaged Foods',
#   'id': 'BRLS'},
#  {'Symbol': 'BRLSW',
#   'Name': 'Borealis Foods Inc. Warrant',
#   'Last Sale': '$0.1175',
#   'Net Change': 0.0025,
#   '% Change': '2.174%',
#   'Market Cap': '2512020.00',
#   'Country': 'Kazakhstan',
#   'IPO Year': '2021',
#   'Volume': 25000,
#   'Sector': 'Consumer Staples',
#   'Industry': 'Packaged Foods',
#   'id': 'BRLSW'},
#  {'Symbol': 'BRLT',
#   'Name': 'Brilliant Earth Group Inc. Class A Common Stock',
#   'Last Sale': '$1.35',
#   'Net Change': -0.17,
#   '% Change': '-11.184%',
#   'Market Cap': '134074173.00',
#   'Country': 'United States',
#   'IPO Year': '2021',
#   'Volume': 241148,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Consumer Specialties',
#   'id': 'BRLT'},
#  {'Symbol': 'BRN',
#   'Name': 'Barnwell Industries Inc. Common Stock',
#   'Last Sale': '$1.20',
#   'Net Change': -0.02,
#   '% Change': '-1.639%',
#   'Market Cap': '12064241.00',
#   'Country': 'United States',
#   'IPO Year': '1965',
#   'Volume': 17366,
#   'Sector': 'Energy',
#   'Industry': 'Oil & Gas Production',
#   'id': 'BRN'},
#  {'Symbol': 'BRNS',
#   'Name': 'Barinthus Biotherapeutics plc American Depositary Shares',
#   'Last Sale': '$0.944',
#   'Net Change': 0.0741,
#   '% Change': '8.518%',
#   'Market Cap': '38080389.00',
#   'Country': 'United Kingdom',
#   'IPO Year': '2021',
#   'Volume': 50293,
#   'Sector': 'Health Care',
#   'Industry': 'Biotechnology: Pharmaceutical Preparations',
#   'id': 'BRNS'},
#  {'Symbol': 'BRO',
#   'Name': 'Brown & Brown Inc. Common Stock',
#   'Last Sale': '$111.77',
#   'Net Change': 1.21,
#   '% Change': '1.094%',
#   'Market Cap': '32034127764.00',
#   'Country': 'United States',
#   'IPO Year': '',
#   'Volume': 1261416,
#   'Sector': 'Finance',
#   'Industry': 'Specialty Insurers',
#   'id': 'BRO'},
#  {'Symbol': 'BROG',
#   'Name': 'Brooge Energy Limited Ordinary Shares',
#   'Last Sale': '$1.4802',
#   'Net Change': 0.1302,
#   '% Change': '9.644%',
#   'Market Cap': '162211940.00',
#   'Country': 'United Kingdom',
#   'IPO Year': '2018',
#   'Volume': 25025,
#   'Sector': 'Energy',
#   'Industry': 'Integrated oil Companies',
#   'id': 'BROG'},
#  {'Symbol': 'BROS',
#   'Name': 'Dutch Bros Inc. Class A Common Stock',
#   'Last Sale': '$73.72',
#   'Net Change': 2.09,
#   '% Change': '2.918%',
#   'Market Cap': '12125643708.00',
#   'Country': 'United States',
#   'IPO Year': '2021',
#   'Volume': 5245840,
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Restaurants',
#   'id': 'BROS'},
#  {'Symbol': 'BRSP',
#   'Name': 'BrightSpire Capital Inc. Class A Common Stock',
#   'Last Sale': '$5.38',
#   'Net Change': -0.01,
#   '% Change': '-0.186%',
#   'Market Cap': '701885533.00',
#   'Country': 'United States',
#   'IPO Year': '2018',
#   'Volume': 406655,
#   'Sector': 'Real Estate',
#   'Industry': 'Real Estate Investment Trusts',
#   'id': 'BRSP'},
#  ...]

# %%
import meilisearch

client = meilisearch.Client('http://localhost:7700', 'aSampleMasterKey')

client.index('nasdaq').add_documents(result_d, primary_key='id')
# Out:
# TaskInfo(task_uid=0, index_uid='nasdaq', status='enqueued', type='documentAdditionOrUpdate', enqueued_at=datetime.datetime(2025, 5, 20, 3, 33, 31, 943336))

# %%
client.index('nasdaq').search('Microsoft')
# Out:
# {'hits': [{'id': 'MSFT',
#    'Symbol': 'MSFT',
#    'Name': 'Microsoft Corporation Common Stock',
#    'Last Sale': '$454.27',
#    'Net Change': 1.14,
#    '% Change': '0.252%',
#    'Market Cap': '3376381701554.00',
#    'Country': 'United States',
#    'IPO Year': '1986',
#    'Volume': 23803441,
#    'Sector': 'Technology',
#    'Industry': 'Computer Software: Prepackaged Software'},
#   {'id': 'MBOT',
#    'Symbol': 'MBOT',
#    'Name': 'Microbot Medical Inc. Common Stock',
#    'Last Sale': '$2.68',
#    'Net Change': 0.01,
#    '% Change': '0.375%',
#    'Market Cap': '93115196.00',
#    'Country': 'Israel',
#    'IPO Year': '',
#    'Volume': 3239936,
#    'Sector': 'Health Care',
#    'Industry': 'Biotechnology: Biological Products (No Diagnostic Substances)'},
#   {'id': 'ALGM',
#    'Symbol': 'ALGM',
#    'Name': 'Allegro MicroSystems Inc. Common Stock',
#    'Last Sale': '$27.51',
#    'Net Change': 0.49,
#    '% Change': '1.813%',
#    'Market Cap': '5065279630.00',
#    'Country': 'United States',
#    'IPO Year': '2020',
#    'Volume': 2214865,
#    'Sector': 'Technology',
#    'Industry': 'Semiconductors'}],
#  'query': 'Microsoft',
#  'processingTimeMs': 3,
#  'limit': 20,
#  'offset': 0,
#  'estimatedTotalHits': 3}
